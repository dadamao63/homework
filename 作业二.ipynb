# %%
#打印所有股票
import numpy as np
import pandas as pd
data=pd.read_excel('sz50.xlsx',None,index_col='datetime')
data.keys()
# Out:
# odict_keys(['600000.XSHG', '600016.XSHG', '600028.XSHG', '600029.XSHG', '600030.XSHG', '600036.XSHG', '600048.XSHG', '600050.XSHG', '600100.XSHG', '600104.XSHG', '600111.XSHG', '600340.XSHG', '600485.XSHG', '600518.XSHG', '600519.XSHG', '600547.XSHG', '600606.XSHG', '600837.XSHG', '600887.XSHG', '600919.XSHG', '600958.XSHG', '600999.XSHG', '601006.XSHG', '601088.XSHG', '601166.XSHG', '601169.XSHG', '601186.XSHG', '601198.XSHG', '601211.XSHG', '601229.XSHG', '601288.XSHG', '601318.XSHG', '601328.XSHG', '601336.XSHG', '601390.XSHG', '601398.XSHG', '601601.XSHG', '601628.XSHG', '601668.XSHG', '601688.XSHG', '601766.XSHG', '601788.XSHG', '601800.XSHG', '601818.XSHG', '601857.XSHG', '601881.XSHG', '601901.XSHG', '601985.XSHG', '601988.XSHG', '601989.XSHG'])

# %%
import pandas as pd
import talib as ta
import numpy as np
stock=pd.DataFrame(pd.read_excel('sz50.xlsx',key='600036.XSGH',index_col='datetime'))
MaArray=ta.MA(stock.close.values,10)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
stock1=pd.read_excel('sz50.xlsx',key='600036.XSGH',index_col='datetime').close
mS=pd.Series(MaArray)
mS.index=pd.date_range('20170103',periods=len(mS),freq='D')
plt.plot(stock1)
plt.plot(mS)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import talib as ta

stock=pd.DataFrame(pd.read_excel('sz50.xlsx',index_col='datetime').close)
ROCArray50=ta.ROCR100(stock50.close.values,timeperiod=5)
df=pd.DataFrame(ROCArray50)


stock=pd.DataFrame(pd.read_excel('sz50.xlsx',key='600000.XSHG',index_col='datetime').close)
ROCArray=ta.ROCR100(stock.close.values,timeperiod=20)
rS=pd.Series(ROCArray)
rS.index=pd.date_range('20170103',periods=len(rS),freq='D')

plt.plot(rS)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-713267f80793> in <module>
#       4 import talib as ta
#       5 stock=pd.DataFrame(pd.read_excel('sz50.xlsx',index_col='datetime').close)
# ----> 6 ROCArray50=ta.ROCR100(stock50.close.values,timeperiod=5)
#       7 df=pd.DataFrame(ROCArray50)
#       8
#
# NameError: name 'stock50' is not defined
